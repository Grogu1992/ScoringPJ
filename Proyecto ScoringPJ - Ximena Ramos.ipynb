# %% [markdown]
# ## Organización: Banco de Bogotá.
#
# ### Objetivos de la organización:
# El Banco de Bogotá fue fundado en 1870, convirtiéndose en la primera institución financiera del país. En la actualidad funciona como banco comercial de primer piso y hace parte del Grupo aval. Como establecimiento de crédito, el Banco de Bogotá tiene como principal objetivo la originación de préstamos mediante la utilización de los recursos de fondeo de los clientes de su pasivo, procurando cumplir con la regulación y normativas vigentes. Para lograr este objetivo, la estructura organizacional del banco se compone de vicepresidencias, que a su vez se componen de gerencias cuyas funciones se centran en cumplir tareas específicas.
#
# ### *Organigrama*

# %% [markdown]
# ![Organigrama.png](attachment:Organigrama.png)

# %% [markdown]
# Las vicepresidencias operan junto con las gerencias mediante la realización de comités con el fin de establecer estrategias para cumplir las metas del negocio. Adicionalmente, se realizan comités generales, usualmente una vez al mes, para revisar las estrategias de las vicepresidencias y medir los indicadores de efectividad.
# Las áreas que intervienen principalmente en el establecimiento de las estrategias para la originación de créditos son la Vicepresidencia de Crédito y la Dirección de Riesgo de Crédito y Tesorería. Estas áreas serán las afectadas con el proyecto que se desea realizar con el presente trabajo.
#
# ### Área Objetivo
# En términos generales, se busca mejorar y acrecentar la colocación de créditos de manera eficiente, es decir disminuyendo el riesgo. El área que implementará las soluciones del presente estudio será la Dirección de Riesgo de Crédito y Tesorería, encargada de la originación masiva de créditos.
# En la actualidad esta Dirección es la encargada de establecer las estrategias de aprobación para la cartera masiva del banco, es decir, los clientes más pequeños que son atendidos a través de la Red de Oficinas.
# Los clientes que llegan con una necesidad específica a la Red de Oficinas del banco son atendidos por asesores comerciales. Estos asesores se hacen cargo de perfilar al cliente ofreciéndole el producto financiero que más se ajuste a su necesidad.
# Si el producto pertenece a la gama de productos ofertados en el activo del banco se inicia un proceso de aprobación de crédito. Para el segmento de personas naturales el banco ha venido utilizando desde hace aproximadamente 12 años una herramienta conocida como el “Flujo de Aprobación de Créditos”, a través de la cual, mediante el uso de información del cliente y el uso de algoritmos parametrizados en la herramienta, se generan ofertas relacionadas con la necesidad específica del solicitante facilitando los procesos y tiempos de desembolso.
#
# Los pasos son los siguientes:
# 1.	El asesor comercial radica una solicitud a nombre del cliente
# 2.	Se toma información general que utilizan los flujos para hacer una “Pre-aprobación” de acuerdo con el perfil del cliente
# 3.	Se solicitan los documentos de soporte de la información suministrada por el cliente
# 4.	Las áreas implicadas realizan la validación documental junto con la corrección de información errónea.
# 5.  Como proceso intermedio, las solicitudes pasan a un análisis cortod y uno a uno, llevado a cabo por un área llamada la "Dirección de Crédito masivo"
# 6.	Se realiza el proceso de “Aprobación final” utilizando nuevamente como herramienta los flujo
# 7.	Se realiza el proceso de desembolso
#
# A continuación se muestra el esquema general del flujo de aprobación de créditos:

# %% [markdown]
# ![EsquemaFlujo.png](attachment:EsquemaFlujo.png)

# %% [markdown]
# Desde hace poco más de 3 años el banco abrió la posibilidad de que el segmento de las personas jurídicas pudieran tener aprobaciones de créditos mediante este flujo. Para esto diseñó una esquema especial alterando algunas partes del proceso, de manera que se pudiera conservar la metodología de aprobación que se venía siguiendo en las áreas de crédito tradicional para este tipo de clientes, pero que permitiera que la aprobación fuera más rápida. Con la utilización de esta herramienta se planeaba pasar de un tiempo promedio de 30 días en la gestión punta a punta en la generación de un crédito a un promedio de 8 días.
#
# A pesar de que el flujo ha mejorado la gestión de créditos para este tipo de clientes, ciertamente no ha logrado sustituir al canal de aprobación tradicional. Por esta razón el flujo de las personas jurídicas es propenso a tener variadas mejoras.
#
# Actualmente, las aprobaciones en el flujo diseñado para las personas jurídicas dependen casi enteramente del análisis uno a uno que realiza la Dirección de Crédito Masivo, por lo que podría decirse que el criterio de aprobación es netamente subjetivo y se conserva gran parte de la metodología del área de Crédito Tadicional. Además se tiene que el nivel de riesgo no es numéricamente medible.
#
# El flujo hoy en día cuenta con scores de clasificación de riesgo (llamados los scores de originación y de comportamiento) para el segmento persona natural y utiliza una serie de variables sociodemográficas y de comportamiento con el sistema financiero para esta asignación. En los inicios del flujo de las personas jurídicas, la clasificación anterior no podía ser replicada debido a que este era un nuevo tipo de cliente, por tal motivo se ha vuelto necesario diseñar un modelo de scoring basado en que ya se cuenta con un histórico de información de 3 años.
#
# Entre las ventajas notables del proceso actual es que se está logrando tener una muestra ampliada de perfiles a analizar. Por otro lado, una de las desventajas más sobresalientes es que no se cuenta con una métrica de medición de riesgo.
#
# ## Objetivos del Proyecto
# En aras de contar una métrica de clasificación apropiada, en el presente proyecto se planea diseñar un score de clasificación para el segmento de las pequeñas empresas que son aprobadas por flujo, el cual permita medir la tasa de perfiles malos y dotar a la herramienta de un mecanismo de toma de decisiones más acertado.
#
# #### •	Preguntas planteadas:
# 1. ¿Cómo clasificar los nuevos clientes?
# 2. ¿Cómo clasificar los existentes?
# 3. ¿Disminuirá con este cambio la tasa de aprobaciones?
# 4. ¿Cómo será el impacto en las provisiones del banco?
#
# #### •	Objetivos adicionales:
# 1. No reducir la tasa de aprobación actual
# 2. Lograr masificar las aprobaciones del flujo para el segmento de las pequeñas empresas
#
# ## Medición del éxito del proyecto - Criterios
#
# #### •	Objetivos:
# Mejorar el criterio de clasificación de riesgo de las personas jurídicas tramitados por flujo, recargando gran parte del criterio de aprobación a los algoritmos del flujo.
#
# #### •	Subjetivos:
# Proveer de una métrica más efectiva a que permita mejorar la confianza que se tiene en la herramienta.
#
# ## Diagnósticos generales:
#
# ### Datos:
# Para este escenario inicial tiene disponible la información de los clientes que han sido evaluados durante los último 3 años a través del flujo de aprobación de personas jurídicas.
#
# Entre los riesgos identificados, es posible que se tenga información incompleta o que la muestra de clientes tenga una significativa reducción debido al porcentaje que llegan al análisis de crédito en la Dirección de Crédito Masivo. Adicionalmente, puede que en un futuro se requiera la calibración de modelo debido a que a la fecha no se han podido evidenciar los efectos de mediano y largo plazo de la pandemia reciente.
#
# ### Inventario de recursos:
# •	No se necesita algún hardware especial. Simplemente computadores con procesadores eficientes
#
# •	Como fuente de datos se tienen las tablas de almacenamiento de la cartera consolidada del banco, y otras fuentes auxiliares en que se guarda la información exclusiva del flujo. Para toda esta data hay restricción de acceso.
#
# •	Como fuente de apoyo podría utilizarse la información de los estados financieros que reportan las empresas a la Superintendencia de Sociedades y escoger una muestra de clientes con un perfil muy similar al del grupo objetivo.
#
# •	Hay personal encargado de actualizar la información del banco en las diferentes fuentes de datos, adicionalmente se tienen recursos expertos en identificar las fuentes de información necesarias adicionales.
#
# ### Requerimientos, supuestos y limitantes:
#
# •	Hay ciertas restricciones de acceso a bases por temas de seguridad, para esto el personal del área de M.I.S (el área de Información Gerencial) puede proveer de toda la información requerida bajo los lineamientos que le sean solicitados.
#
# •	Probablemente, si se requiere información adicional relacionada con consulta a centrales de riesgo, por ejemplo, se deba invertir un poco más en presupuesto
#
# •	Las personas del área de riesgo ya se encuentran familiarizadas con este tipo de proyectos ya que en ocasiones anteriores la Organización ha contratado estos servicios.
#
# •	Se tiene acceso limitado a cierto tipo de información y para externos se cuenta con contrato de confidencialidad
#
# #### Riesgos y Contingencias
# •	Es posible que la información no sea suficiente para logar identificar comportamientos a largo plazo.
#
# •	Se debe tener en cuenta dentro del presupuesto gastos adicionales relacionados con la consulta de información externa que no sea pública.
#
# •	Debido a que el Flujo de Personas Jurídicas no está totalmente masificado, puede que las cifras no reflejen verdaderamente el comportamiento del segmento. Adicionalmente puede que haya habido un cambio estructural que pueda impactar los resultados debido a la pandemia. En estos casos se recomienda recalibrar los modelos especialmente cuando se haya culminado una senda de tiempo lo suficientemente amplia.
#
# ### Terminología
# •	*Segmento Masivo*: Se refiere al grupo de clientes que, segùn su nivel de ventas o de activos, se clasifican como clientes pequeños.
#
# •	*Segmento no Masivo*: Todos los clientes que no pertenecen al segmento masivo.
#
# •	*Segmentación*: Agrupación asignada al momento de clasificar un grupo objetivo
#
# •	*Flujo*: Herramienta de aprobación de créditos para el segmento masivo.
#
# •	*Crédito Tradicional*: Área que realiza otorgamiento de créditos mediante un análisis extenso y uno a uno de los clientes.
#
# •	*Nivel de riesgo*: Probabilidad de que ocurra un evento inesperado. En este caso de que se incurra en el imcumplimiento.
#
# •	*Perfiles Buenos/Malos*: Agrupación que depende del nivel de riesgo.
#
# •	*Originación / Colocación*: Proceso de desembolso de nuevos créditos.
#
# •	*Mercado*: Grupo de entidades del sistema financiero comparables con el Banco de Bogotá.
#
#
# ### Análisis Costo/Beneficio:
# •	Se estima que cada consulta a centrales de riesgo es de 4.000. Por el momento no se tiene mapeo de otros costos adicionales
#
# •	El despliegue de resultados requiere que el área encargada de hacer desarrollos en el flujo integre todas las variables necesarias para ejecutar y procesar resultados. Esto implica un presupuesto en horas por parte de los desarrolladores.
#
# ## Objetivos del proyecto de minería de datos
#
# •	El tipo análisis de datos corresponde a una tarea se segmentación a través de scoring.
#
# •	Este tipo de segmentación es válida para la clasificación de clientes entre buenos y malos. La ventana predictiva es válida durante un año, o hasta que se actualice la información financiera del cliente cada trimestre. Esto siempre y cuando no se tengan cambios estructurales en el tiempo o cambios relevantes en la actividad que ejercen los clientes.
#
# ### Criterio de éxito
#
# •	En primera instancia, se consideraría un éxito el hecho de que, con la información que se tiene, se logre la elaboración de un modelo que segmenten apropiadamente la cartera del banco y que al tiempo se genere crecimiento.
#
# •	Con la segmentación proporcionada por los modelos a elaborar, se planea que los indicadores de cartera vencida del segmento de pequeñas empresas disminuyan y que se promocione la utilización de flujo.
#
# •	En línea con el punto anterior, en cuanto a indicadores de la cartera “mala” de este tipo de clientes se espera que estén por debajo de los del mercado y que al mismo tiempo se aumenten los niveles de colocación de cartera.
#
# •	Adicionalmente se espera que los usuarios que tienen interacción con el flujo depositen en él un mayor nivel de confianza en cuanto a criterios de aprobación
